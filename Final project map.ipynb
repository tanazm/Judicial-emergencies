# %%
import requests
import json
import numpy as np
import pandas as pd
from pandas import json_normalize
# Out:
# /Users/tanazmeghjani/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
with open('US_JD_simply.json') as json_data:
    geometry_data = json.load(json_data)

# %%
df = pd.DataFrame.from_dict(json_normalize(geometry_data['features']), orient='columns')

# %%
df['properties.name'] = df['properties.DISTRICT'].apply(lambda x: x.title())

# %%
pd.set_option("display.max_rows", 100)
df
# Out:
#        type  id geometry.type  \
# 0   Feature   1       Polygon
# 1   Feature   2       Polygon
# 2   Feature   3  MultiPolygon
# 3   Feature   4  MultiPolygon
# 4   Feature   5       Polygon
# 5   Feature   6       Polygon
# 6   Feature   7       Polygon
# 7   Feature   8  MultiPolygon
# 8   Feature   9  MultiPolygon
# 9   Feature  10  MultiPolygon
# 10  Feature  11       Polygon
# 11  Feature  12       Polygon
# 12  Feature  13       Polygon
# 13  Feature  14       Polygon
# 14  Feature  15       Polygon
# 15  Feature  16  MultiPolygon
# 16  Feature  17  MultiPolygon
# 17  Feature  18  MultiPolygon
# 18  Feature  19       Polygon
# 19  Feature  20       Polygon
# 20  Feature  21  MultiPolygon
# 21  Feature  22  MultiPolygon
# 22  Feature  23       Polygon
# 23  Feature  24       Polygon
# 24  Feature  25       Polygon
# 25  Feature  26       Polygon
# 26  Feature  27       Polygon
# 27  Feature  28       Polygon
# 28  Feature  29       Polygon
# 29  Feature  30       Polygon
# ...

# %%
df_map = pd.merge(df_SN7577i_c, df_SN7577i_d, how='inner', left_on = 'Id', right_on = 'Id')
